# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('Losses-test-5000-1.csv')
# Out:
#       Epochs  PDE Loss  Boundary Conditions Loss
# 0          0  0.006970                  0.416048
# 1          1  0.007404                  0.317427
# 2          2  0.006247                  0.297524
# 3          3  0.004984                  0.273330
# 4          4  0.003184                  0.233012
# ...      ...       ...                       ...
# 4996    4996  0.032386                  0.020340
# 4997    4997  0.037042                  0.021891
# 4998    4998  0.038615                  0.018380
# 4999    4999  0.034695                  0.022529
# 5000    5000  0.032561                  0.022395
#
# [5001 rows x 3 columns]

# %%
pd.read_csv('Losses-test-5000-2.csv')
# Out:
#       Epochs  PDE Loss  Boundary Conditions Loss
# 0          0  0.014921                  0.710273
# 1          1  0.000878                  0.430621
# 2          2  0.003264                  0.313069
# 3          3  0.010858                  0.310593
# 4          4  0.013008                  0.337015
# ...      ...       ...                       ...
# 4996    4996  0.029743                  0.022331
# 4997    4997  0.027574                  0.020444
# 4998    4998  0.033671                  0.017114
# 4999    4999  0.031499                  0.022276
# 5000    5000  0.030929                  0.020823
#
# [5001 rows x 3 columns]
